# %%
import pandas as pd
import numpy as np

# %%
filename = 'california_raw_utf8.csv'

# %%
# NON_KWH, MEM_KWH, MEMBERSHIP, MIN_RATE, FLAT_FEE 
convert_dict = {
    'Cost: Pay As You Go: $1.99/session + starting at $0.35/kWh, $3.00 for reservations; Evgo Member: starting at $0.35/kWh, $3.00 for reservations, prepaid charging credit: $4.99; EVgo Plusâ„¢: starting at $0.30/kWh, free for reservations, Membership fee: $6.99/month': [0.35, 0.30, 6.99, 'NULL', 'NULL'],
    'Cost: 0.00$ / Free': [0, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.35$ / kWh Time not charging: $120/hr after 30 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Pay As You Go: $1.99/session + starting at $0.39/kWh, $3.00 for reservations; Evgo Member: starting at $0.39/kWh, $3.00 for reservations, prepaid charging credit: $4.99; EVgo Plusâ„¢: starting at $0.29/kWh, free for reservations, Membership fee: $6.99/month': [0.39, 0.29, 6.99, 'NULL', 'NULL'],
    'Cost: 0.43$ / kWh Membership rate: $0.31/kWh. Membership fee: $4.00/month': [0.43, 0.31, 4, 'NULL', 'NULL'],
    'Cost: Free': [0, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Mon-Sun (5PM-5PM) $0.15 per kWh (Fee: $0.12 plus taxes)': [0.15, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.2 USD per kWh Parking 0.08 USD per minute': [0.2, 'NULL', 'NULL', 0.08, 'NULL'],
    'Cost: Pay As You Go: $1.99/session + starting at $0.29/kWh, $3.00 for reservations; Evgo Member: starting at $0.29/kWh, $3.00 for reservations, prepaid charging credit: $4.99; EVgo Plusâ„¢: starting at $0.25/kWh, free for reservations, Membership fee: $6.99/month': [0.29, 0.25, 6.99, 'NULL', 'NULL'],
    'Cost: Unknown': ['NULL', 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.35$ / kWh Time not charging: $5/hr after 20 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Parking 0.5 USD per minute Flat Fee 0 USD': ['NULL', 'NULL', 'NULL', 0.5, 'NULL'],
    'Cost: 0.29$ / kWh $0.29/kWh: 17:00-17:00, 0-30kWhs, Maximum power of 50 KW': [0.29, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.35$ / kWh $0.35/kWh: 17:00-17:00, 0-30kWhs, Maximum power of 50 KW': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Min payment: $5.00, Max payment: $15.00, Max session time: 1 hour.': ['NULL', 'NULL', 'NULL', 0.25, 'NULL'],
    'Cost: $4.95/session + $0.20/min': ['NULL', 'NULL', 'NULL', 0.2, 4.95],
    'Cost: 0.30$ / kWh Time not charging: $10/hr after 60 mins': [0.3, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.35 USD per kWh Parking 0 USD per minute for first 30 mins Parking 0.5 USD per minute after 30 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.29 USD per kWh Parking 0 USD per hour Flat Fee 0 USD': [0.29, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: stations cost to charge.': ['NULL', 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.50$ / kWh': [0.5, 'NULL', 'NULL' 'NULL', 'NULL', 'NULL'],
    'Cost: 0.19$ / kWh': [0.19, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.23 USD per kWh Parking 0 USD per minute for first 60 mins Parking 0.1 USD per minute after 60 mins':[0.23, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.23 USD per kWh Parking 0 USD per minute for first 120 mins Parking 5 USD per hour after 120 mins': [0.23, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.2 USD per kWh Parking 0 USD per minute for first 60 mins Parking 5 USD per hour after 60 mins': [0.2, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.495 USD per kWh Parking 0 USD per minute for first 90 mins Parking 0.1 USD per minute after 90 mins': [0.5, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.15 USD per kWh Parking 0.15 USD per minute': [0.15, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.15 USD per kWh Parking 0.15 USD per minute Flat Fee 0 USD': [0.15, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.13$ / kWh Time not charging: $6/hr after 60 mins': [0.13, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Parking 0 USD per hour for first 120 mins Parking 3 USD per hour after 120 mins Max Fee 30 USD for every 24 hr(s)': [0, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.35 USD per kWh Parking 0 USD per minute for first 60 mins Parking 5 USD per hour after 60 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.35 USD per kWh Parking 0 USD per minute for first 60 mins Parking 2 USD per hour after 60 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy MONDAY,TUESDAY,WEDNESDAY,THURSDAY,FRIDAY 00:00 AM - 4:00 PM 0.445 USD per kWh MONDAY,TUESDAY,WEDNESDAY,THURSDAY,FRIDAY 4:00 PM - 9:00 PM 0.585 USD per kWh MONDAY,TUESDAY,WEDNESDAY,THURSDAY,FRIDAY 9:00 PM - 11:59 PM 0.445 USD per kWh SATURDAY,SUNDAY 0.445 USD per kWh Parking 0 USD per minute for first 90 mins Parking 0.1 USD per minute after 90 mins': [0.58, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 20.00$ / Hour': ['NULL', 'NULL', 'NULL', .33, 'NULL'],
    'Cost: Energy 00:00 AM - 06:00 AM 0.2375 USD per kWh 06:00 AM - 4:00 PM 0.4192 USD per kWh 4:00 PM - 9:00 PM 0.6674 USD per kWh 9:00 PM - 11:59 PM 0.4192 USD per kWh': [0.66, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0 USD per minute for first 210 mins Parking 10 USD per hour after 210 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.30$ / kWh': [0.3, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 00:00 AM - 4:00 PM 0.35 USD per kWh 4:00 PM - 9:00 PM 0.55 USD per kWh 9:00 PM - 11:59 PM 0.35 USD per kWh Parking 0 USD per minute for first 60 mins Parking 2 USD per hour after 60 mins': [0.55, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.27$ / kWh Time not charging: $30/hr after 30 mins': [0.27, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.24$ / kWh Time not charging: $15/hr after 10 mins': [0.24, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.21$ / Minute': [0.21, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.20$ / kWh Time not charging: $3/hr after 30 mins': [0.2, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.29$ / kWh': [0.29, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.49$ / kWh': [0.49, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.28$ / Hour Time not charging: $3/hr after 45 mins': [0.28, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.35$ / kWh': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Mon-Sun (5PM-5PM) $0.50 per kWh for first 1 minutes then $0.50 per kWh': [0.5, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.40$ / kWh': [0.4, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.45$ / kWh Time not charging: $1/hr after 15 mins': [0.45, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.41 USD per kWh Parking 0 USD per hour for first 300 mins Parking 3 USD per hour after 300 mins': [0.41, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.24$ / kWh Time not charging: $1/hr after 60 mins': [0.24, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.69 USD per kWh Parking 0 USD per hour for first 120 mins Parking 10 USD per hour after 120 mins': [0.69, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 30.00$ / Hour Time not charging: $30/hr': ['NULL', 'NULL', 'NULL', 0.5, 'NULL'],
    'Cost: Energy 0.3 USD per kWh Parking 1 USD per hour': [0.3, 'NULL', 'NULL', 0.02, 'NULL'],
    'Cost: 29.40$ / Hour Time not charging: $29.4/hr': ['NULL', 'NULL', 'NULL', 0.49, 'NULL'],
    'Cost: Energy 0.2 USD per kWh Parking 0 USD per hour': [0.2, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.3069 USD per kWh Parking 0 USD per hour Min Fee 0 USD Max Fee 0.31 USD': [0.3, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.4 USD per kWh Parking 0 USD per hour for first 60 mins Parking 2 USD per hour after 60 mins': [0.4, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Parking 0 USD per hour Flat Fee 5.99 USD Min Fee 5.99 USD Max Fee 6.99 USD': ['NULL', 'NULL', 'NULL', 'NULL', 5.99],
    'Cost: Energy 0.41 USD per kWh Parking 0 USD per hour for first 240 mins Parking 3 USD per hour after 240 mins': [0.41, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Pay As You Go: $0.99/session + starting at $0.32/kWh, $3.00 for reservations; Evgo Member: starting at $0.28/kWh, $3.00 for reservations, prepaid charging credit: $4.99; EVgo Plusâ„¢: starting at $0.25/kWh, free for reservations, Membership fee: $6.99/month': [0.32, 0.28, 6.99, 'NULL', 'NULL'],
    'Cost: 2.00$ / Hour $2/hr: 0-120 mins': ['NULL', 'NULL', 'NULL', 0.03, 'NULL'],
    'Cost: Energy 0 USD per kWh Parking 0 USD per hour for first 60 mins Parking 5 USD per hour after 60 mins': [0, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.25$ / kWh': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.25$ / kWh Time not charging: $5/hr after 30 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 1.50$ / Hour': ['NULL', 'NULL', 'NULL', 0.03, 'NULL'],
    'Cost: 0.28$ / kWh $0.28/kWh: 17:00-17:00, Maximum power of 50 KW': [0.28, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Mon-Sun (4PM-5PM) $0.00 per Hour, Mon-Sun (5PM-8PM) $0.00 per Hour, Mon-Sun (8PM-12AM) $0.00 per Hour, Mon-Sun (12AM-4PM) $0.00 per Hour': [0, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Parking 0 USD per hour Flat Fee 20 USD': [0, 'NULL', 'NULL', 'NULL', 20],
    'Cost: 0.26$ / kWh Time not charging: $1/hr after 60 mins': [0.26, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.24 USD per kWh Parking 0 USD per minute for first 60 mins Parking 1 USD per minute after 60 mins': [0.24, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.21$ / kWh': [0.21, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0 USD per hour for first 180 mins Parking 1 USD per hour after 180 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.19 USD per kWh Parking 0 USD per minute for first 60 mins Parking 0.1 USD per minute after 60 mins': [0.19, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0 USD per kWh Parking 0 USD per minute for first 60 mins Parking 0.2 USD per minute after 60 mins': [0, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.47 USD per kWh Parking 0 USD per minute for first 60 mins Parking 0.1 USD per minute after 60 mins': [0.47, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.55$ / kWh Time not charging: $60/hr after 15 mins': [0.55, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0 USD per minute for first 60 mins Parking 5 USD per hour after 60 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Mon-Sun (5PM-5PM) $0.30 per kWh (Fee: $0.50 plus taxes)': [0.3, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: While charging: 0.00/hr for 0-30 mins + 0.30/kWh for 30-75 mins + 1.00/kWh after 75 mins + While parked, not charging: 1.00/hr': [0.3, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.35$ / kWh Time not charging: $12/hr after 15 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.24$ / kWh': [0.24, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.26 USD per kWh Parking 0 USD per hour for first 240 mins Parking 1.5 USD per hour after 240 mins': [0.26, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.2 USD per kWh Parking 0.35 USD per minute': [0.2, 'NULL', 'NULL', 0.35, 'NULL'],
    'Cost: 0.40/kWh + While parked, not charging: 5.00/hr after 30 mins + Flat fee: 1.00': [0.4, 'NULL', 'NULL', 'NULL', 1],
    'Cost: Flat fee: 1.00 + 0.37/kWh + While parked, not charging: 5.00/hr after 30 mins': [0.37, 'NULL', 'NULL', 'NULL', 1],
    'Cost: 0.35/kWh + Flat fee: 1.00 + While parked, not charging: 5.00/hr after 30 mins': [0.35, 'NULL', 'NULL', 'NULL', 1],
    'Cost: Flat fee: 1.00 + 0.30/kWh + While parked, not charging: 5.00/hr after 30 mins': [0.3, 'NULL', 'NULL', 'NULL', 1],
    'Cost: 0.28$ / kWh': [0.28, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Flat fee: 1.00 + 0.35/kWh + While parked, not charging: 5.00/hr after 30 mins': [0.35, 'NULL', 'NULL', 'NULL', 1],
    'Cost: 0.39$ / kWh $0.39/kWh: 17:00-17:00, Maximum power of 50 KW': [0.39, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost:': ['NULL', 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 2 USD per kWh Parking 20 USD per hour': [2, 'NULL', 'NULL', 0.33, 'NULL'],
    'Cost: Energy 0.28 USD per kWh Flat Fee 3 USD': [0.28, 'NULL', 'NULL', 'NULL', 3],
    'Cost: Energy 2 USD per kWh Parking 3 USD per minute': [2, 'NULL', 'NULL', 3, 'NULL'],
    'Cost: 0.45$ / kWh': [0.45, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.30$ / kWh $0.45/kWh from 4pm-9pm.': [0.45, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Flat fee: 1.00 + 0.30/kWh': [0.3, 'NULL', 'NULL', 'NULL', 1],
    'Cost: $0.45.': [0.45, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.4 USD per kWh Parking 0 USD per minute for first 240 mins Parking 1.5 USD per minute after 240 mins': [0.4, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: .49 kWH.': [0.49, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: .49/kWH.': [0.49, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: $0.49/kWH.': [0.49, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: $0.49 kWh.': [0.49, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Parking 0.05 USD per minute for first 60 mins Parking 0.1 USD per minute after 60 mins': ['NULL', 'NULL', 'NULL', 0.05, 'NULL'],
    'Cost: Pricing varies, see Tesla website for details': ['NULL', 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.18 USD per kWh Parking 0 USD per minute for first 30 mins Parking 0.25 USD per minute after 30 mins': [0.18, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 00:00 AM - 4:00 PM 0.495 USD per kWh 4:00 PM - 9:00 PM 0.585 USD per kWh 9:00 PM - 11:59 PM 0.495 USD per kWh Parking 0 USD per minute for first 90 mins Parking 0.1 USD per minute after 90 mins': [0.58, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 1.50$ / Hour Time not charging: $1.5/hr': ['NULL', 'NULL', 'NULL', 0.02, 'NULL'],
    'Cost: 0.43$ / kWh': [0.43, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.15 USD per kWh Parking 0.05 USD per minute Min Fee 5 USD Max Fee 50 USD': [0.15, 'NULL', 'NULL', 0.05, 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0.1 USD per minute for first 60 mins Parking 0 USD per minute after 60 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.40$ / kWh Time not charging: $5/hr': [0.4, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.31$ / kWh': [0.31, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.15$ / kWh': [0.15, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0 USD per kWh Parking 0 USD per hour': [0, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 1.00$ / Hour': [0, 'NULL', 'NULL', 0.2, 'NULL'],
    'Cost: 0.20$ / kWh': [0.2, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0.1 USD per minute': [0.25, 'NULL', 'NULL', 0.1, 'NULL'],
    'Cost: 0.50$ / kWh Time not charging: $20/hr after 15 mins': [0.5, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 5.00$ / Session': ['NULL', 'NULL', 'NULL', 'NULL', 5],
    'Cost: 0.46$ / kWh Time not charging: $60/hr after 15 mins': [0.46, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.50$ / kWh Time not charging: $15/hr after 10 mins': [0.5, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.37$ / kWh': [0.37, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 15.00$ / Hour Time not charging: $15/hr': ['NULL', 'NULL', 'NULL', 0.25, 'NULL'],
    'Cost: $0.49 kWH.': [0.49, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.42$ / kWh': [0.42, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Pay As You Go: $1.99/session + starting at $0.35/kWh, $3.00 for reservations; Evgo Member: starting at $0.35/kWh, $3.00 for reservations, prepaid charging credit: $4.99; EVgo Plus": starting at $0.30/kWh, free for reservations, Membership fee: $6.99/month': [0.35, 0.3, 6.99, 'NULL', 'NULL'],
    'Cost: 15.00$ / Hour $15/hr: 17:00-17:00, 0-30kWhs, Maximum power of 50 KW': ['NULL', 'NULL', 'NULL', 0.25, 'NULL'],
    'Cost: Parking 06:00 AM - 4:00 PM 1 USD per hour Parking 4:00 PM - 06:00 AM 0.5 USD per hour Min Fee 0.5 USD': ['NULL', 'NULL', 'NULL', 0.02, 'NULL'],
    'Under solar panel across from access road. Cost: $1.50/hr then $5/hr after 4 hours': ['NULL', 'NULL', 'NULL', 0.03, 'NULL'],
    'Cost: Energy MONDAY,TUESDAY,WEDNESDAY,THURSDAY,FRIDAY 00:00 AM - 6:00 PM 0.25 USD per kWh MONDAY,TUESDAY,WEDNESDAY,THURSDAY,FRIDAY 6:00 PM - 9:30 PM 0.2 USD per kWh MONDAY,TUESDAY,WEDNESDAY,THURSDAY,FRIDAY 9:30 PM - 11:59 PM 0.15 USD per kWh SATURDAY,SUNDAY 0.15 USD per kWh': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.35$ / kWh Time not charging: $5/hr after 15 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 08:30 AM - 9:30 PM 0.25 USD per kWh 9:30 PM - 08:30 AM 0.2 USD per kWh Flat Fee 1.25 USD': [0.25, 'NULL', 'NULL', 'NULL', 1.25],
    'Cost: 12.00$ / Hour Time not charging: $12/hr': ['NULL', 'NULL', 'NULL', 0.2, 'NULL'],
    'Cost: Energy 0.2 USD per kWh Parking 0.1 USD per minute Min Fee 5 USD': [0.2, 'NULL', 'NULL', 0.1, 'NULL'],
    'Cost: Free Free: 17:00-17:00, Maximum power of 50 KW': [0, 'NULL', 'NULL', 0, 'NULL'],
    'Cost: Energy 0.55 USD per kWh Flat Fee 1 USD': [0.55, 'NULL', 'NULL', 'NULL', 1],
    'Cost: Energy 0.18 USD per kWh Parking 0 USD per minute for first 30 mins Parking 0.05 USD per minute after 30 mins': [0.18, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0 USD per minute for first 30 mins Parking 0.1 USD per minute after 30 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.22$ / kWh Time not charging: $5/hr after 30 mins': [0.22, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Mon-Sun (5PM-5PM) $5.00 per Hour (Fee: $5.00 plus taxes)': ['NULL', 'NULL', 'NULL', 0.08, 'NULL'],
    'Cost: Energy 0.7 USD per kWh Parking 0 USD per minute for first 90 mins Parking 0.25 USD per minute after 90 mins Flat Fee 0 USD Max Fee 50 USD': [0.7, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 1.00$ / Hour Time not charging: $1/hr': ['NULL', 'NULL', 'NULL', 0.02, 'NULL'],
    'Cost: 0.18$ / kWh Time not charging: $6/hr after 5 mins': [0.18, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0 USD per minute Flat Fee 0 USD': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.2 USD per kWh Parking 0 USD per minute for first 45 mins Parking 5 USD per hour after 45 mins': [0.2, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.12$ / kWh Time not charging: $3/hr after 60 mins': [0.12, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.35$ / kWh Time not charging: $5/hr after 10 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 2 USD per hour': [0.25, 'NULL', 'NULL', 0.33, 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0 USD per hour for first 60 mins Parking 3 USD per hour after 60 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.19 USD per kWh Parking 0 USD per minute for first 60 mins Parking 4 USD per hour after 60 mins': [0.19, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.23 USD per kWh Parking 0 USD per minute for first 30 mins Parking 0.1 USD per minute after 30 mins': [0.23, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.10$ / kWh': [0.1, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0 USD per hour for first 240 mins Parking 2.5 USD per hour after 240 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.18$ / kWh': [0.18, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.1189 USD per kWh Parking 0.5 USD per hour': [0.12, 'NULL', 'NULL', 0.01, 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0 USD per hour for first 270 mins Parking 2.5 USD per hour after 270 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.40/kWh + While parked, not charging: 10.00/hr after 15 mins + While charging: 2.00/hr after 50 mins': [0.4, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: $0.10/kWh for staff, $0.20/kWh for public.': [0.2, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 9.00$ / Session': ['NULL', 'NULL', 'NULL', 'NULL', 9],
    'Cost: Energy 00:00 AM - 4:00 PM 0.4 USD per kWh 4:00 PM - 9:00 PM 0.47 USD per kWh 9:00 PM - 11:59 PM 0.4 USD per kWh Parking 0 USD per minute for first 60 mins Parking 5 USD per hour after 60 mins': [0.47, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.50$ / kWh Time not charging: $5/hr': [0.5, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.25$ / kWh Time not charging: $5/hr after 15 mins': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.45$ / kWh $0.45/kWh: 16:00-16:00, Maximum power of 50 KW': [0.45, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.40$ / kWh $0.4/kWh: 17:00-17:00, Maximum power of 50 KW': [0.4, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: $0.29.': [0.29, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 00:00 AM - 08:00 AM 0.35 USD per kWh 08:00 AM - 8:00 PM 0.5 USD per kWh 8:00 PM - 11:59 PM 0.35 USD per kWh Min Fee 1.5 USD': [0.5, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: $0.49 /kWH.': [0.49, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.35$ / kWh $0.35/kWh: 17:00-17:00, Maximum power of 50 KW': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 1 USD per hour for first 240 mins Parking 5 USD per hour after 240 mins Min Fee 2 USD Max Fee 50 USD': [0.25, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking 0.04 USD per minute': [0.25, 'NULL', 'NULL', 0.04, 'NULL'],
    'Cost: 0.23$ / kWh': [0.23, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Mon-Sun (5PM-5PM) $0.23 per kWh (Fee: $0.35 plus taxes)': [0.23, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 00:00 AM - 4:00 PM 0.445 USD per kWh 4:00 PM - 9:00 PM 0.545 USD per kWh 9:00 PM - 11:59 PM 0.445 USD per kWh Parking 0 USD per minute for first 120 mins Parking 0.1 USD per minute after 120 mins': [0.55, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Mon-Sun (5PM-5PM) $0.25 per kWh (Fee: $1.99 plus taxes)': [0.25, 'NULL', 'NULL', 'NULL', 1.99],
    'Cost: 0.35$ / kWh Time not charging: $18/hr after 30 mins': [0.35, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.57$ / kWh Time not charging: $60/hr after 15 mins': [0.57, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 00:00 AM - 4:00 PM 0.5 USD per kWh 4:00 PM - 9:00 PM 0.65 USD per kWh 9:00 PM - 11:59 PM 0.5 USD per kWh Parking (While not charging) 4 USD per hour After 60 mins of grace Period Parking (While plugged in) For first 1 hr(s) Free': [0.65, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 00:00 AM - 5:00 PM 0.4 USD per kWh 5:00 PM - 11:59 PM 0.5 USD per kWh Parking 0 USD per hour for first 60 mins Parking 0.15 USD per minute after 60 mins': [0.5, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Energy 0.25 USD per kWh Parking (While not charging) 10 USD per hour After 15 mins of grace Period Parking (While plugged in) For first 15 mins 0.15 USD per minute Flat Fee 4.95 USD': [0.25, 'NULL', 'NULL', 'NULL', 4.95],
    'Cost: Energy 0.5175 USD per kWh Parking 0 USD per minute for first 90 mins Parking 0.15 USD per minute after 90 mins': [0.52, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 0.20$ / kWh Time not charging: $6/hr after 5 mins': [0.2, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: Pay As You Go: $1.99/session + starting at $0.35/kWh, $3.00 for reservations; Evgo Member: starting at $0.35/kWh, $3.00 for reservations, prepaid charging credit: $4.99; EVgo Plus™: starting at $0.30/kWh, free for reservations, Membership fee: $6.99/month': [0.35, 0.3, 6.99, 'NULL', 'NULL'],
    'Cost: Energy 0.38 USD per kWh Parking 0 USD per minute for first 120 mins Parking 5 USD per hour after 120 mins': [0.38, 'NULL', 'NULL', 'NULL', 'NULL'],
    'Cost: 10.00$ / Hour': ['NULL', 'NULL', 'NULL', 0.16, 'NULL'],
    'Cost: Energy 0.31 USD per kWh Parking 0 USD per hour for first 120 mins Parking 2 USD per hour after 120 mins': [0.31, 'NULL', 'NULL', 'NULL', 'NULL']
}

# %%
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#                                           STATION NETWORK  \
# 0                               E.A.T Marketplace    EVgo
# 1                             Palm Springs Nissan    None
# 2  Larry H. Miller Nissan Corona Parts Department    None
# 3                            Mossy Nissan - Poway    None
# 4          Larry H Miller Nissan - San Bernardino    None
#
#                     ADDRESS            CITY STATE    ZIP  CHARGE_SPEED  \
# 0          41952 6th Street        Temecula    CA  92590  125 A, 50 kW
# 1           68177 Kyle Road  Cathedral City    CA  92234     ? A, ? kW
# 2         2575 Wardlow Road          Corona    CA  92882     ? A, ? kW
# 3          14100 Poway Road           Poway    CA  92064     ? A, ? kW
# 4  735 Showcase Drive South  San Bernardino    CA  92408     ? A, ? kW
#
#                                            PRICE_RAW
# 0  Cost: Pay As You Go: $1.99/session + starting ...
# 1                                 Cost: 0.00$ / Free
# ...

# %% [markdown]
# GET AMPS AND KW

# %%
amps_lst = []
kw_lst = []

# %%
def unit_value(speed, unit):
  speed = speed.replace(unit, '')
  speed = speed.replace(' ', '')

  if '?' in speed:
    return 'NULL'
  else:
    return speed

# %%
for i in range(len(df)):
  try:
    charge_speed = df['CHARGE_SPEED'][i]
    amps, kw = charge_speed.split(',')

    amps = unit_value(amps, 'A')
    amps_lst.append(amps)

    kw = unit_value(kw, 'kW')
    kw_lst.append(kw)
    
  except:
    amps_lst.append('?')
    kw_lst.append('?')

# %%
df['AMPS'] = amps_lst
df['KW'] = kw_lst

# %% [markdown]
# EXTRACT PRICING INFOMATION

# %%
non_rate_lst = []
mem_rate_lst = []
membership_fee_lst = []
min_rate_lst = []
flat_fee_lst = []

# %%
for i in range(len(df)):
  price_info = df['PRICE_RAW'][i]
  non_rate, mem_rate, membership_fee, min_rate, flat_fee = convert_dict[price_info]

  non_rate_lst.append(non_rate)
  mem_rate_lst.append(mem_rate)
  membership_fee_lst.append(membership_fee)
  min_rate_lst.append(min_rate)
  flat_fee_lst.append(flat_fee)

# %%
df['NON_KWH'] = non_rate_lst
df['MEM_KWH'] = mem_rate_lst
df['MEM_FEE_PER_MONTH'] = membership_fee_lst
df['RATE_PER_MIN'] = min_rate_lst
df['FLATE_FEE'] = flat_fee_lst

# %%
df.head()
# Out:
#                                           STATION NETWORK  \
# 0                               E.A.T Marketplace    EVgo
# 1                             Palm Springs Nissan    None
# 2  Larry H. Miller Nissan Corona Parts Department    None
# 3                            Mossy Nissan - Poway    None
# 4          Larry H Miller Nissan - San Bernardino    None
#
#                     ADDRESS            CITY STATE    ZIP  CHARGE_SPEED  \
# 0          41952 6th Street        Temecula    CA  92590  125 A, 50 kW
# 1           68177 Kyle Road  Cathedral City    CA  92234     ? A, ? kW
# 2         2575 Wardlow Road          Corona    CA  92882     ? A, ? kW
# 3          14100 Poway Road           Poway    CA  92064     ? A, ? kW
# 4  735 Showcase Drive South  San Bernardino    CA  92408     ? A, ? kW
#
#                                            PRICE_RAW  AMPS    KW NON_KWH  \
# 0  Cost: Pay As You Go: $1.99/session + starting ...   125    50    0.35
# ...

# %%
df.to_csv(f'{filename}_clean.csv')
